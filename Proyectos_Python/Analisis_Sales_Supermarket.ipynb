# %% [markdown]
# # Supermarket Sales Exploartory Analisis ( Pandas--Python)
# Data source: https://www.kaggle.com

# %% [markdown]
# ## Libraries

# %%
# 📊 DATA ANALYSIS AND VISUALIZATION LIBRARIES

import pandas as pd                             # Data manipulation and analysis (DataFrames, cleaning, transformation)
import numpy as np                              # Numerical computations (arrays, math operations)
import matplotlib.pyplot as plt                 # Basic plotting (line, bar, scatter, histograms)
import seaborn as sns                           # Advanced, beautiful statistical plots built on top of Matplotlib
import calmap                                   # Calendar heatmaps (visualizing time-series data by date)
from ydata_profiling import ProfileReport       # Automatic exploratory data analysis (EDA) reports
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       6 import seaborn as sns                           # Advanced, beautiful statistical plots built on top of Matplotlib
#       7 import calmap                                   # Calendar heatmaps (visualizing time-series data by date)
# ----> 8 from ydata_profiling import ProfileReport       # Automatic exploratory data analysis (EDA) reports
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %%
import urllib.request
filename = "https://github.com/correotrabajoomar-a11y/Portafolio_Omar_Castro/blob/main/Proyectos_Python/Datasets/supermarket_sales.csv?raw=true"
df = pd.read_csv(filename)

# %%
df.head(15)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      A     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974      B   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
#
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                   float64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
# date Object
df["Date"] = pd.to_datetime(df["Date"])
# Out:
# C:\Users\ilove\AppData\Local\Temp\ipykernel_844\3238882695.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Date"]
# Out:
# 0      2019-01-05
# 1      2019-03-08
# 2      2019-03-03
# 3      2019-01-27
# 4      2019-02-08
#           ...
# 998    2019-02-22
# 999    2019-02-18
# 1000   2019-02-18
# 1001   2019-03-10
# 1002   2019-01-26
# Name: Date, Length: 1003, dtype: datetime64[ns]

# %%
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                          float64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
df.set_index("Date", inplace=True)

# %%
df.head(10)
# Out:
#              Invoice ID Branch       City Customer type  Gender  \
# Date
# 2019-01-05  750-67-8428      A     Yangon        Member  Female
# 2019-03-08  226-31-3081      C  Naypyitaw        Normal  Female
# 2019-03-03  631-41-3108      A     Yangon        Normal    Male
# 2019-01-27  123-19-1176      A     Yangon        Member    Male
# 2019-02-08  373-73-7910      A     Yangon        Normal    Male
# 2019-03-25  699-14-3026      C  Naypyitaw        Normal    Male
# 2019-02-25  355-53-5943      A     Yangon        Member  Female
# 2019-02-24  315-22-5665      C  Naypyitaw        Normal  Female
# 2019-01-10  665-32-9167      A     Yangon        Member  Female
# 2019-02-20  692-92-5582      B   Mandalay        Member  Female
#
#                       Product line  Unit price  Quantity   Tax 5%     Total  \
# Date
# 2019-01-05       Health and beauty       74.69       7.0  26.1415  548.9715
# 2019-03-08  Electronic accessories       15.28       5.0   3.8200   80.2200
# ...

# %%
df.describe()
# Out:
#        Unit price    Quantity       Tax 5%        Total         cogs  \
# count  996.000000  983.000000  1003.000000  1003.000000  1003.000000
# mean    55.764568    5.501526    15.400368   323.407726   308.007358
# std     26.510165    2.924673    11.715192   246.019028   234.303836
# min     10.080000    1.000000     0.508500    10.678500    10.170000
# 25%     33.125000    3.000000     5.894750   123.789750   117.895000
# 50%     55.420000    5.000000    12.096000   254.016000   241.920000
# 75%     78.085000    8.000000    22.539500   473.329500   450.790000
# max     99.960000   10.000000    49.650000  1042.650000   993.000000
#
#        gross margin percentage  gross income       Rating
# count             1.003000e+03   1003.000000  1003.000000
# mean              4.761905e+00     15.400368     6.972682
# std               8.886215e-16     11.715192     1.717647
# min               4.761905e+00      0.508500     4.000000
# ...

# %% [markdown]
# # Task 2: Univariate Analisys
# Question 1 = What does the customer distribution look like?  Is it skewed?

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Rating'], kde=True)

plt.axvline(x=np.mean(df['Rating']), color='r', linestyle='--', label='Mean')
plt.axvline(x=np.percentile(df['Rating'], 25), color='g', linestyle='--', label='25th Percentile')
plt.axvline(x=np.percentile(df['Rating'], 75), color='g', linestyle='--', label='75th Percentile')

plt.title('Distribution of Ratings with Mean and Percentiles')
plt.legend()
plt.show()

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Unit price'}>,
#         <Axes: title={'center': 'Quantity'}>,
#         <Axes: title={'center': 'Tax 5%'}>],
#        [<Axes: title={'center': 'Total'}>,
#         <Axes: title={'center': 'cogs'}>,
#         <Axes: title={'center': 'gross margin percentage'}>],
#        [<Axes: title={'center': 'gross income'}>,
#         <Axes: title={'center': 'Rating'}>, <Axes: >]], dtype=object)

# %% [markdown]
# Question 2: Do aggregate sales numbers differ much between branches?

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Branch', data=df, palette=['#1f77b4', '#ff7f0e', '#2ca02c'] )
plt.title('Number of Sales per Branch')
plt.show()
# Out:
# C:\Users\ilove\AppData\Local\Temp\ipykernel_844\1957344282.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Branch', data=df, palette=['#1f77b4', '#ff7f0e', '#2ca02c'] )

# %%
df['Branch'].value_counts()
# Out:
# Branch
# A    342
# B    333
# C    328
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Payment', data=df, palette=["#f33434","#054585","#034c03"] )
plt.title('Different Payment Methods Used')
plt.show()
# Out:
# C:\Users\ilove\AppData\Local\Temp\ipykernel_844\1942346602.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Payment', data=df, palette=["#f33434","#054585","#034c03"] )
